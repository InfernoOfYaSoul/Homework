# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline



with open("B_stat.txt", 'r') as f:
    stat = f.readlines()

x = [float(i.split(' ')[0]) for i in stat]
y = [float(i.split(' ')[1]) for i in stat]
z = [float(i.split(' ')[2]) for i in stat]

plt.title('-') # заголовок
plt.xlabel('x') # ось абсцисс
plt.ylabel('y, y2') # ось ординат
plt.grid() # включение отображение сетки
plt.scatter(x, y, 3, 'r')
plt.scatter(x, np.log(z) * 100, 3, 'r')
plt.plot(x, 200 * np.log(x) - 180, 3, 'b')
plt.plot(x, np.power(x, 2)/670 , 3, 'b')
# Out:
# <ipython-input-23-d3d729b426b3>:20: RuntimeWarning: divide by zero encountered in log
#   plt.scatter(x, np.log(z) * 100, 3, 'r')
# <ipython-input-23-d3d729b426b3>:21: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, 200 * np.log(x) - 180, 3, 'b')
# [<matplotlib.lines.Line2D at 0x7f938975a310>,
#  <matplotlib.lines.Line2D at 0x7f938975a370>]
