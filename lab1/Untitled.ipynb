# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline



with open("1lin_output.txt", 'r') as f:
    stat = f.readlines()

x = [float(i.split(' ')[0]) for i in stat]
y = [float(i.split(' ')[1]) for i in stat]

plt.title('-') # заголовок
plt.xlabel('x') # ось абсцисс
plt.ylabel('y, y2') # ось ординат
plt.grid() # включение отображение сетки
#plt.plot(x, y)
plt.scatter(x, y, 3, 'r')
#plt.scatter(x, 5*np.log(x) - 19, 3, 'r')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline



with open("1bin_output.txt", 'r') as f:
    stat = f.readlines()

x = [float(i.split(' ')[0]) for i in stat]
y = [float(i.split(' ')[1]) for i in stat]

plt.title('-') # заголовок
plt.xlabel('x') # ось абсцисс
plt.ylabel('y, y2') # ось ординат
plt.grid() # включение отображение сетки
#plt.plot(x, y)
plt.scatter(x, y, 3, 'b')
plt.scatter(x, 5*np.log(x) - 19, 3, 'r')

# %%
with open("2sumfnd_output.txt", 'r') as f:
    stat = f.readlines()

x = [float(i.split(' ')[0]) for i in stat]
y = [float(i.split(' ')[1]) for i in stat]
#ys= [float(i ** 2) for i in stat]

plt.title('Квадратичная зависимость') # заголовок
plt.xlabel('x') # ось абсцисс
plt.ylabel('y, y2') # ось ординат
plt.grid() # включение отображение сетки
#plt.plot(x, y)
plt.scatter(x, y, 3, 'r')
plt.plot(x, np.power(x, 2)/1500 , 3, 'b')

# %%
with open("2sumfnd_fast_output.txt", 'r') as f:
    stat = f.readlines()

x = [float(i.split(' ')[0]) for i in stat]
y = [float(i.split(' ')[1]) for i in stat]
#ys= [float(i ** 2) for i in stat]

plt.title('Линейная зависимость') # заголовок
plt.xlabel('x') # ось абсцисс
plt.ylabel('y, y2') # ось ординат
plt.grid() # включение отображение сетки
#plt.plot(x, y)
plt.scatter(x, y, 3, 'r')
plt.plot(x, np.array(x) / 750, 3, 'b')

# %%
with open("3A_1.txt", 'r') as f:
    stat = f.readlines()

x = [float(i.split(' ')[0]) for i in stat]
y = [float(i.split(' ')[1]) for i in stat]
#ys= [float(i ** 2) for i in stat]

plt.title('-') # заголовок
plt.xlabel('x') # ось абсцисс
plt.ylabel('y, y2') # ось ординат
plt.grid() # включение отображение сетки
#plt.plot(x, y)
plt.scatter(x, y, 3, 'r')
#plt.ylim([1, 12])
plt.plot(x, np.array(x) / 790, 3, 'b')

# %%
with open("3A_2.txt", 'r') as f:
    stat = f.readlines()

x = [float(i.split(' ')[0]) for i in stat]
y = [float(i.split(' ')[1]) for i in stat]
#ys= [float(i ** 2) for i in stat]

plt.title('-') # заголовок
plt.xlabel('x, elements') # ось абсцисс
plt.ylabel('y, microsec') # ось ординат
plt.grid() # включение отображение сетки
#plt.plot(x, y)
plt.scatter(x, y, 3, 'r')
#plt.ylim([0.05, 0.2])
plt.plot(x, np.array(x) / 790, 3, 'b')

# %%
with open("3B_1.txt", 'r') as f:
    stat = f.readlines()

x = [float(i.split(' ')[0]) for i in stat]
y = [float(i.split(' ')[1]) for i in stat]
#ys= [float(i ** 2) for i in stat]

plt.title('-') # заголовок
plt.xlabel('x') # ось абсцисс
plt.ylabel('y, micros') # ось ординат
plt.grid() # включение отображение сетки
#plt.plot(x, y)
plt.scatter(x, y, 3, 'r')
plt.plot(x, np.array(x) / 125, 3, 'b')
#plt.ylim([7, 11])
#plt.plot(x, np.array(x) / 750, 3, 'b')

# %%
with open("3B_2.txt", 'r') as f:
    stat = f.readlines()

x = [float(i.split(' ')[0]) for i in stat]
y = [float(i.split(' ')[1]) for i in stat]
#ys= [float(i ** 2) for i in stat]

plt.title('-') # заголовок
plt.xlabel('x, elements') # ось абсцисс
plt.ylabel('y, microsec') # ось ординат
plt.grid() # включение отображение сетки
#plt.plot(x, y)
plt.scatter(x, y, 3, 'r')
plt.plot(x, np.array(x) / 125, 3, 'b')

# %%
with open("3C_1.txt", 'r') as f:
    stat = f.readlines()

x = [float(i.split(' ')[0]) for i in stat]
y = [float(i.split(' ')[1]) for i in stat]
#ys= [float(i ** 2) for i in stat]

plt.title('-') # заголовок
plt.xlabel('x') # ось абсцисс
plt.ylabel('y, micros') # ось ординат
plt.grid() # включение отображение сетки
#plt.plot(x, y)
plt.scatter(x, y, 3, 'r')
#plt.ylim([2, 3])
plt.plot(x, np.array(x) / 205, 3)

# %%
with open("3C_2.txt", 'r') as f:
    stat = f.readlines()

x = [float(i.split(' ')[0]) for i in stat]
y = [float(i.split(' ')[1]) for i in stat]
#ys= [float(i ** 2) for i in stat]

plt.title('-') # заголовок
plt.xlabel('x') # ось абсцисс
plt.ylabel('y, micros') # ось ординат
plt.grid() # включение отображение сетки
#plt.plot(x, y)
plt.scatter(x, y, 3, 'r')
#plt.ylim([0, 5000])
plt.plot(x, np.array(x) / 205, 3)
